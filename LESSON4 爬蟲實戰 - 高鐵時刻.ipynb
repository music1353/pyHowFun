# %% [markdown]
# ## 190830更新
# 因高鐵網站之後採用call api獲取json資料的方式，因此可以直接透過`requests.post(api)`的方式來獲取資料，這樣也節省了解析html的時間
# * 透過"開發人員工具"查看資源url
# <img src="https://i.imgur.com/qfs18do.png" alt="drawing" width="700"/>
# ---
# <img src="https://i.imgur.com/9dwFddd.png" alt="drawing" width="400"/>

# %%
# 查詢高鐵時刻api：http://www.thsrc.com.tw/tw/TimeTable/Search
# 台北→台南, 2019/08/30, 5:30後啟程的班車

import requests
from bs4 import BeautifulSoup

url = 'http://www.thsrc.com.tw/tw/TimeTable/Search'

# 找到option值
form_data = {
    'StartStation':'977abb69-413a-4ccf-a109-0272c24fd490',
    'StartStationName': '台北站',
    'EndStation':'9c5ac6ca-ec89-48f8-aab0-41b738cb1814',
    'EndStationName': '台南站',
    'DepartueSearchDate':'2019/08/30',
    'DepartueSearchTime':'05:30',
    'SearchType':'S'
}

# 用request.post，並放入form_data
response_post = requests.post(url, data=form_data)
response_post.text
# Out:
# '{"success":true,"data":{"DepartureTable":{"Title":{"TitleSplit1":"台北站","TitleSplit2":"台南站&nbsp;&nbsp;2019/08/30(五)&nbsp;&nbsp;05:30"},"TrainItem":[{"TrainNumber":"0803","DepartureTime":"06:26","DestinationTime":"08:26","Duration":"02:00","NonReservedCar":"4","Discount":[{"Id":"68d9fc7b-7330-44c2-962a-74bc47d2ee8a","Name":"大學生","Value":"75折","Color":"#e45916"}],"Note":"","Sequence":0,"StationInfo":[{"StationNo":"01","StationName":"南港站","DepartureTime":"06:15","Show":true,"ColorClass":"orange"},{"StationNo":"02","StationName":"台北站","DepartureTime":"06:26","Show":true,"ColorClass":"purple"},{"StationNo":"03","StationName":"板橋站","DepartureTime":"06:34","Show":true,"ColorClass":"dark_green"},{"StationNo":"04","StationName":"桃園站","DepartureTime":"06:49","Show":true,"ColorClass":"light_green"},{"StationNo":"05","StationName":"新竹站","DepartureTime":"07:02","Show":true,"ColorClass":"gray"},{"StationNo":"06","StationName":"苗栗站","DepartureTime":"07:13","Show":true,"ColorClass":"sky_blue"},{"StationNo":"07","StationName":"台中站","DepartureTime":"07:32","Show":true,"ColorClass":"pink"},{"StationNo":"08","StationName":"彰化站","DepartureTime":"07:45","Show":true,"ColorClass":"red"},{"StationNo":"09","StationName":"雲林站","DepartureTime":"07:56","Show":true,"ColorClass":"dark_blue"},{"StationNo":"10","StationName":"嘉義站","DepartureTime":"08:10","Show":true,"ColorClass":"yellow"},{"StationNo":"11","StationName":"台南站","DepartureTime":"08:28","Show":true,"ColorClass":"brown"},{"StationNo":"12","StationName":"左營站","DepartureTime":"08:40","Show":true,"ColorClass":"blue"}]},{"TrainNumber":"0203","DepartureTime":"06:30","DestinationTime":"08:01","Duration":"01:31","NonReservedCar":"3","Discount":[],"Note":"","Sequence":1,"StationInfo":[{"StationNo":"01","StationName":"南港站","DepartureTime":"","Show":false,"ColorClass":"orange"},{"StationNo":"02","StationName":"台北站","DepartureTime":"06:30","Show":true,"ColorClass":"purple"},{"StationNo":"03","StationName":"板橋站","DepartureTime":"06:38","Show":true,"ColorClass":"dark_green"},{"StationNo":"04","StationName":"桃園站","DepartureTime":"","Show":false,"ColorClass":"light_green"},{"StationNo":"05","StationName":"新竹站","DepartureTime":"","Show":false,"ColorClass":"gray"},{"StationNo":"06","StationName":"苗栗站","DepartureTime":"","Show":false,"ColorClass":"sky_blue"},{"StationNo":"07","StationName":"台中站","DepartureTime":"07:20","Show":true,"ColorClass":"pink"},{"StationNo":"08","StationName":"彰化站","DepartureTime":"","Show":false,"ColorClass":"red"},{"StationNo":"09","StationName":"雲林站","DepartureTime":"","Show":false,"ColorClass":"dark_blue"},{"StationNo":"10","StationName":"嘉義站","DepartureTime":"07:45","Show":true,"ColorClass":"yellow"},{"StationNo":"11","StationName":"台南站","DepartureTime":"08:03","Show":true,"ColorClass":"brown"},{"StationNo":"12","StationName":"左營站","DepartureTime":"08:15","Show":true,"ColorClass":"blue"}]},{"TrainNumber":"0603","DepartureTime":"06:51","DestinationTime":"08:37","Duration":"01:46","NonReservedCar":"4","Discount":[],"Note":"","Sequence":2,"StationInfo":[{"StationNo":"01","StationName":"南港站","DepartureTime":"06:40","Show":true,"ColorClass":"orange"},{"StationNo":"02","StationName":"台北站","DepartureTime":"06:51","Show":true,"ColorClass":"purple"},{"StationNo":"03","StationName":"板橋站","DepartureTime":"07:00","Show":true,"ColorClass":"dark_green"},{"StationNo":"04","StationName":"桃園站","DepartureTime":"07:15","Show":true,"ColorClass":"light_green"},{"StationNo":"05","StationName":"新竹站","DepartureTime":"07:27","Show":true,"ColorClass":"gray"},{"StationNo":"06","StationName":"苗栗站","DepartureTime":"","Show":false,"ColorClass":"sky_blue"},{"StationNo":"07","StationName":"台中站","DepartureTime":"07:53","Show":true,"ColorClass":"pink"},{"StationNo":"08","StationName":"彰化站","DepartureTime":"","Show":false,"ColorClass":"red"},{"StationNo":"09","StationName":"雲林站","DepartureTime":"","Show":false,"ColorClass":"dark_blue"},{"StationNo":"10","StationName":"嘉義站","DepartureTime":"08:19","Show":true,"ColorClass" ...

# %%
import json

# 用json解析
data = json.loads(response_post.text)
data

# 取出
data['data']['TrainItem']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-0dc8516a1972> in <module>
#       6
#       7 # 取出
# ----> 8 data['data']['TrainItem']
#
# KeyError: 'TrainItem'

# %%
trainItem = data['data']['DepartureTable']['TrainItem']

# 所有班車(train_number)
train_number = []
for item in trainItem:
    train_number.append(item['TrainNumber'])
    
# 所有出發時間(departure_time)
departure_time = []
for item in trainItem:
    departure_time.append(item['DepartureTime'])

# 所有到達時間(arrival_time)
arrival_time = []
for item in trainItem:
    arrival_time.append(item['DestinationTime'])

# 所有行車時間(duration)
duration = []
for item in trainItem:
    duration.append(item['Duration'])

# %%
# 整理成表格
import pandas as pd

highway_df = pd.DataFrame({
    '車次': train_number,
    '出發時間': departure_times,
    '到達時間': arrival_times,
    '行車時間': duration},
    columns = ['車次', '出發時間', '到達時間', '行車時間'])

highway_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-dd720c090cbd> in <module>
#       4 highway_df = pd.DataFrame({
#       5     '車次': train_number,
# ----> 6     '出發時間': departure_times,
#       7     '到達時間': arrival_times,
#       8     '行車時間': duration},
#
# NameError: name 'departure_times' is not defined

# %% [markdown]
# (⁎⁍̴̛ᴗ⁍̴̛⁎) -----  我是分隔線 ----- (⁎⁍̴̛ᴗ⁍̴̛⁎)

# %%
# 查詢高鐵時刻：http://www.thsrc.com.tw/tw/TimeTable/SearchResult
# 台北→台南, 2017/11/30, 5:30後啟程的班車

import requests
from bs4 import BeautifulSoup

url = 'http://www.thsrc.com.tw/tw/TimeTable/SearchResult'

# 找到option值
form_data = {
    'StartStation':'977abb69-413a-4ccf-a109-0272c24fd490',
    'EndStation':'9c5ac6ca-ec89-48f8-aab0-41b738cb1814',
    'SearchDate':'2017/11/30',
    'SearchTime':'05:30',
    'SearchWay':'DepartureInMandarin'
}

# 用request.post，並放入form_data
response_post = requests.post(url, data=form_data)

soup_post = BeautifulSoup(response_post.text, 'lxml')
soup_post

# %%
# 所有班車(train_number)
td_col1 = soup_post.find_all('td', {'class':'column1'})
train_numbers = []

for tag in td_col1:
    # print(tag)
    train_number = tag.text
    train_numbers.append(train_number)
    
print(train_numbers)

# %%
# 所有出發時間(departure_time)
td_col3 = soup_post.find_all('td', {'class':'column3'})
departure_times = []

for tag in td_col3:
    departure_time = tag.text
    departure_times.append(departure_time)
    
print(departure_times)

# %%
# 所有到達時間(arrival_time)
td_col4 = soup_post.find_all('td', {'class':'column4'})
arrival_times = []

for tag in td_col4:
    arrival_time = tag.text
    arrival_times.append(arrival_time)
    
print(arrival_times)

# %%
# 所有行車時間(travel_time)
td_col2 = soup_post.find_all('td', {'class':'column2'})
travel_times = []

for tag in td_col2:
    travel_time = tag.text
    travel_times.append(travel_time)
    
print(travel_times)

# %%
# 整理成表格
import pandas as pd

highway_df = pd.DataFrame({
    '車次': train_numbers,
    '出發時間': departure_times,
    '到達時間': arrival_times,
    '行車時間': travel_times},
    columns = ['車次', '出發時間', '到達時間', '行車時間'])

highway_df
